# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Automobile.csv')

# %%
df.head(5)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
# find the percentage of null value in age columns
(df['normalized-losses'].isnull().sum()/len(df['normalized-losses']))*100
# Out:
# 20.0

# %%
# drop Canbin column
df.drop('normalized-losses', axis=1, inplace=True)

# %%
df.drop('num-of-doors', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['symboling', 'make', 'fuel-type', 'aspiration', 'body-style',
#        'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width',
#        'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# symboling            0
# make                 0
# fuel-type            0
# aspiration           0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
df['bore'].fillna(df['bore'].mean(), inplace=True)

# %%
df['stroke'].fillna(df['stroke'].mean(), inplace=True)

# %%
df['horsepower'].fillna(df['horsepower'].mean(), inplace=True)

# %%
df['peak-rpm'].fillna(df['peak-rpm'].mean(), inplace=True)

# %%
df['price'].fillna(df['price'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling            0
# make                 0
# fuel-type            0
# aspiration           0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False) #all null values removed
# Out:
# <Axes: >

# %%
sns.pairplot(df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
for i in df.columns:
    plt.title(i)
    #sns.scatterplot(df[i], df['price'])
    sns.scatterplot(x=df[i],y=df['price'])
    plt.show()

# %%
bestvar1 = ['wheel-base','length','width','weigth','engine-size']

# %%
sns.distplot(df['price'])
# Out:
# C:\Users\Idrees\AppData\Local\Temp\ipykernel_6404\444587821.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ### Data Preprocessing

# %%
df.columns
# Out:
# Index(['symboling', 'make', 'fuel-type', 'aspiration', 'body-style',
#        'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width',
#        'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
df1 = df.drop({'make','length','width','aspiration','body-style','drive-wheels','height',"engine-location"},axis=1)

# %%
df1.columns
# Out:
# Index(['symboling', 'fuel-type', 'wheel-base', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df1
# Out:
#      symboling fuel-type  wheel-base  curb-weight engine-type  \
# 0            3       gas        88.6         2548        dohc
# 1            3       gas        88.6         2548        dohc
# 2            1       gas        94.5         2823        ohcv
# 3            2       gas        99.8         2337         ohc
# 4            2       gas        99.4         2824         ohc
# ..         ...       ...         ...          ...         ...
# 200         -1       gas       109.1         2952         ohc
# 201         -1       gas       109.1         3049         ohc
# 202         -1       gas       109.1         3012        ohcv
# 203         -1    diesel       109.1         3217         ohc
# 204         -1       gas       109.1         3062         ohc
#
#     num-of-cylinders  engine-size fuel-system  bore  stroke  \
# 0               four          130        mpfi  3.47    2.68
# 1               four          130        mpfi  3.47    2.68
# ...

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
df1['fuel-type']= label_encoder.fit_transform(df['fuel-type']) 
df1['fuel-type'].unique()
# Out:
# array([1, 0])

# %%
df1
# Out:
#      symboling  fuel-type  wheel-base  curb-weight engine-type  \
# 0            3          1        88.6         2548        dohc
# 1            3          1        88.6         2548        dohc
# 2            1          1        94.5         2823        ohcv
# 3            2          1        99.8         2337         ohc
# 4            2          1        99.4         2824         ohc
# ..         ...        ...         ...          ...         ...
# 200         -1          1       109.1         2952         ohc
# 201         -1          1       109.1         3049         ohc
# 202         -1          1       109.1         3012        ohcv
# 203         -1          0       109.1         3217         ohc
# 204         -1          1       109.1         3062         ohc
#
#     num-of-cylinders  engine-size fuel-system  bore  stroke  \
# 0               four          130        mpfi  3.47    2.68
# 1               four          130        mpfi  3.47    2.68
# ...

# %%
df1['engine-type']= label_encoder.fit_transform(df['engine-type']) 
df1['engine-type'].unique()
# Out:
# array([0, 5, 3, 2, 6, 4, 1])

# %%
df1['fuel-system']= label_encoder.fit_transform(df['fuel-system']) 
df1['fuel-system'].unique()
# Out:
# array([5, 1, 4, 0, 7, 2, 3, 6])

# %%
# converting num-of-cylinders column into numbers from text
pip install word2number
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
from word2number import w2n

# %%
nums = []
for i in df1['num-of-cylinders']:
    x = w2n.word_to_num(i)
    nums.append(x)
df1['num-of-cylinders'] = nums

# %%
df1
# Out:
#      symboling  fuel-type  wheel-base  curb-weight  engine-type  \
# 0            3          1        88.6         2548            0
# 1            3          1        88.6         2548            0
# 2            1          1        94.5         2823            5
# 3            2          1        99.8         2337            3
# 4            2          1        99.4         2824            3
# ..         ...        ...         ...          ...          ...
# 200         -1          1       109.1         2952            3
# 201         -1          1       109.1         3049            3
# 202         -1          1       109.1         3012            5
# 203         -1          0       109.1         3217            3
# 204         -1          1       109.1         3062            3
#
#      num-of-cylinders  engine-size  fuel-system  bore  stroke  \
# 0                   4          130            5  3.47    2.68
# 1                   4          130            5  3.47    2.68
# ...

# %% [markdown]
# ## Linear Regression
#
# #### Self Analysis based feature

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import numpy as np
import statsmodels.api as sm

# %%
X = df1[['horsepower']]#.values.reshape(1,-1)
y = df1[['price']]#.values.reshape(1,-1)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.7,random_state=42)

# %%
LR = LinearRegression()

# %%
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(X_test)

# %%
r2_score(y_pred,y_test)
# Out:
# 0.029356580769868246

# %%
print('Coefficient is',LR.coef_[0][0])
print('intercept is',LR.intercept_[0])
# Out:
# Coefficient is 142.35846647956447
# intercept is -1764.2932280412697

# %%
tips = sns.load_dataset(df1)
#g = sns.jointplot(x="total_bill", y="tip", data=tips, kind='reg')
#sns.plt.show()

# %%
g = sns.jointplot(x="horsepower", y="price", data=df1, kind='reg')
regline = g.ax_joint.get_lines()[0]
regline.set_color('red')
regline.set_zorder(5)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.scatter(X,y)
plt.plot(X,LR.predict(X))
plt.xlabel('HorsePower')
plt.ylabel('Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.886
# Model:                            OLS   Adj. R-squared (uncentered):              0.885
# Method:                 Least Squares   F-statistic:                              1578.
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):                    5.74e-98
# Time:                        23:26:03   Log-Likelihood:                         -2044.9
# No. Observations:                 205   AIC:                                      4092.
# Df Residuals:                     204   BIC:                                      4095.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### We see the Regression LIne is in Best Fit
#
# ###### RFE selected Feature

# %%
from sklearn.feature_selection import RFE
from sklearn.preprocessing import MinMaxScaler

# %%
X = df1.drop('price',axis=1)
y = df1['price']
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.7,random_state=42)

# %%
scaler = MinMaxScaler()
X_train1 = scaler.fit_transform(X_train)

# %%
model = LinearRegression()

# %%
rfe = RFE(model, step=1)

# %%
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression())

# %%
X_train.columns[rfe.support_]
# Out:
# Index(['symboling', 'fuel-type', 'engine-type', 'num-of-cylinders', 'bore',
#        'compression-ratio', 'highway-mpg'],
#       dtype='object')

# %%
## Model Building
X = df1[['bore']]
y = df1[['price']]
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.7,random_state=42)
LR = LinearRegression()
LR.fit(X_train,y_train)
y_pred1 = LR.predict(X_train)
print("R2 score is",r2_score(y_pred,y_test))
print('Coefficient is',LR.coef_[0][0])
print('intercept is',LR.intercept_[0])
# Out:
# R2 score is 0.029356580769868246
# Coefficient is 14442.714291344062
# intercept is -34646.559510247214

# %%
plt.scatter(X,y)
plt.plot(X,LR.predict(X))
plt.xlabel('Boreratio')
plt.ylabel('Price')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
g = sns.jointplot(x='bore',y='price', data=df1, kind='reg',
                 joint_kws={'line_kws':{'color':'red'}})
plt.xlabel('Boreration')
plt.ylabel('Price')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(37.597222222222214, 0.5, 'Price')

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.772
# Model:                            OLS   Adj. R-squared (uncentered):              0.771
# Method:                 Least Squares   F-statistic:                              691.9
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):                    1.79e-67
# Time:                        23:37:29   Log-Likelihood:                         -2115.4
# No. Observations:                 205   AIC:                                      4233.
# Df Residuals:                     204   BIC:                                      4236.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Multiple Linear Regression
#
# Self Analysis based Features

# %%
df1.columns
# Out:
# Index(['symboling', 'fuel-type', 'wheel-base', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
X = df1.drop('price',axis=1)
y = df1['price']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.7,random_state=42)

# %%
LR.fit(X_train.values,y_train)
# Out:
# LinearRegression()

# %%
y_pred = LR.predict(X_test)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
r2_score(y_pred,y_test)
# Out:
# 0.7565870382447021

# %%
print('Coefficient is',LR.coef_)
print('intercept is',LR.intercept_)
# Out:
# Coefficient is [ 3.08578677e+02 -7.87637310e+02  2.17228857e+02  3.51161106e-01
#   5.29432340e+02 -2.08191339e+03  1.92581028e+02  1.06961146e+02
#  -4.53963347e+03 -4.52557521e+03  1.98522650e+02  4.04382295e+00
#   2.54769646e+00 -7.30715750e+01 -1.20640064e+02]
# intercept is -6053.838322763433

# %%
model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.956
# Model:                            OLS   Adj. R-squared (uncentered):              0.952
# Method:                 Least Squares   F-statistic:                              272.1
# Date:                Sun, 24 Mar 2024   Prob (F-statistic):                   1.37e-119
# Time:                        23:39:31   Log-Likelihood:                         -1948.0
# No. Observations:                 205   AIC:                                      3926.
# Df Residuals:                     190   BIC:                                      3976.
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### RFE Based Features

# %%
from sklearn.feature_selection import RFE
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
model = LinearRegression()

# %%
## Selecting Top 7 Features
rfe = RFE(estimator=model, n_features_to_select=7)
X_train1 = scaler.fit_transform(X_train)

# %%
rfe.fit(X_train1,y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=7)

# %%
X_train.columns[rfe.support_]
# Out:
# Index(['num-of-cylinders', 'engine-size', 'bore', 'stroke',
#        'compression-ratio', 'peak-rpm', 'city-mpg'],
#       dtype='object')

# %%
print("Num Features: %s" % (rfe.n_features_))
print("Selected Features: %s" % (rfe.support_))
print("Feature Ranking: %s" % (rfe.ranking_))
# Out:
# Num Features: 7
# Selected Features: [False False False False False  True  True False  True  True  True False
#   True  True False]
# Feature Ranking: [6 8 2 7 4 1 1 9 1 1 1 5 1 1 3]

# %%
# Out:
#      num-of-cylinders  engine-size  bore  stroke  compression-ratio  peak-rpm  \
# 0                   4          130  3.47    2.68                9.0    5000.0
# 1                   4          130  3.47    2.68                9.0    5000.0
# 2                   6          152  2.68    3.47                9.0    5000.0
# 3                   4          109  3.19    3.40               10.0    5500.0
# 4                   5          136  3.19    3.40                8.0    5500.0
# ..                ...          ...   ...     ...                ...       ...
# 200                 4          141  3.78    3.15                9.5    5400.0
# 201                 4          141  3.78    3.15                8.7    5300.0
# 202                 6          173  3.58    2.87                8.8    5500.0
# 203                 6          145  3.01    3.40               23.0    4800.0
# 204                 4          141  3.78    3.15                9.5    5400.0
#
#      city-mpg
# 0          21
# ...

# %%
X = df1[["num-of-cylinders","engine-size", "bore", "stroke", "compression-ratio", "peak-rpm", "city-mpg"]]
y = df1['price']
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=.7,random_state=42)

# %%
LR = LinearRegression()
LR.fit(X_train,y_train)
y_pred1 = LR.predict(X_train)
print("R2 score is",r2_score(y_pred,y_test))
print('intercept is',LR.intercept_)
print('Coefficient are',LR.coef_)
# Out:
# R2 score is 0.7565870382447021
# intercept is 23380.28817692862
# Coefficient are [-2.47110927e+03  2.12906737e+02 -4.93606627e+03 -4.72392294e+03
#   3.79154419e+02  2.03739799e+00 -3.51205066e+02]
